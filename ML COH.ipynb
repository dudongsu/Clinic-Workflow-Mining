# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_excel(r'C:\Users\mkhazaieli\Documents\COH-PlanApproval-Analysis-210317.xlsx')
dataset.head()
# Out:
#    OrderId       MRN   PatId   Last_Name  First_Name Completed_First_Sim  \
# 0   303014    162967   27323    PETERSEN  CRAIG ALAN 2021-03-08 14:00:00
# 1   303350  11152663  209776  THOMASSIAN       OSHIN 2021-03-09 15:00:00
# 2   302804  11048425  131262     JOHNSON    LAWRENCE 2021-03-05 14:00:00
# 3   302426  11152935  209264      CONARD        ALAN 2021-03-04 08:00:00
# 4   303124  11124646  192816         LIU       RUHUA 2021-03-09 10:00:00
#
#             Plan_Approval Complete_First_Treatment  Clinic_Days_Sim_Treat  \
# 0 2021-03-15 13:46:47.853      2021-03-16 14:30:00                    6.0
# 1 2021-03-15 15:46:20.243      2021-03-16 14:30:00                    5.0
# 2 2021-03-15 13:58:29.673      2021-03-16 14:00:00                    7.0
# 3 2021-03-15 14:07:58.713      2021-03-16 10:30:00                    8.0
# 4 2021-03-15 18:35:23.303      2021-03-16 10:15:00                    5.0
#
#    Clinic_Days_PlanApproval_Treat  Cal_Days_Sim_Treat  \
# ...

# %%
dataset.describe()
# Out:
#              OrderId           MRN          PatId  Clinic_Days_Sim_Treat  \
# count    2080.000000  2.080000e+03    2080.000000            2033.000000
# mean   263297.368269  1.016151e+07  138087.317308               5.764879
# std     23368.492671  2.572744e+06   56440.089978               3.846310
# min    223003.000000  1.006130e+05   11714.000000             -21.000000
# 25%    243198.000000  1.017943e+07   85722.750000               4.000000
# 50%    264767.500000  1.107464e+07  165134.500000               6.000000
# 75%    284090.000000  1.110986e+07  183735.000000               7.000000
# max    303949.000000  1.115373e+07  209776.000000              42.000000
#
#        Clinic_Days_PlanApproval_Treat  Cal_Days_Sim_Treat  \
# count                     2080.000000         2033.000000
# mean                         1.783654            8.146090
# std                          3.205983            5.486724
# min                        -24.000000          -29.000000
# ...

# %%
x = dataset.loc[:,["Clinic_Days_Sim_Treat","Attending","Sim_Dosimetrist","Tx_Technique"]]
y = dataset.loc[:,"Clinic_Days_PlanApproval_Treat"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.6, random_state=0)

# %%
# should encode categorical using one hot encoding or any other method...

from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in astype(self, dtype, copy)
#     430                 new_cats = np.asarray(self.categories)
# --> 431                 new_cats = new_cats.astype(dtype=dtype, copy=copy)
#     432             except (
#
# ValueError: could not convert string to float: 'Amini, Arya '
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-f6150c49cb9d> in <module>
#       1 from sklearn.tree import DecisionTreeRegressor
# ----> 2 X_train = X_train.astype('float')
#       3 regressor = DecisionTreeRegressor()
#       4 regressor.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
# ...
